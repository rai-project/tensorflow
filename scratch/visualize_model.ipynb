# %%
from __future__ import print_function
import os
from io import BytesIO
import numpy as np
from functools import partial
import PIL.Image
from IPython.display import clear_output, Image, display, HTML

import tensorflow as tf

# %%
model_fn = '/Users/chengli/Downloads/1.1_frozen_model.pb'

# %%
# creating TensorFlow session and loading the model
graph = tf.Graph()
sess = tf.InteractiveSession(graph=graph)
with tf.gfile.FastGFile(model_fn, 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
t_input = tf.placeholder(np.float32, name='input') # define the input tensor
imagenet_mean = 117.0
t_preprocessed = tf.expand_dims(t_input-imagenet_mean, 0)
tf.import_graph_def(graph_def)
[print(n.name) for n in tf.get_default_graph().as_graph_def().node]
# Out:
# input
# sub/y
# sub
# ExpandDims/dim
# ExpandDims
# import/data
# import/Pad/paddings
# import/Pad
# import/conv1_weight
# import/conv1_weight/read
# import/convolution
# import/conv1_bias
# import/conv1_bias/read
# import/add
# import/relu_conv1
# import/PadV2/paddings
# import/PadV2/constant_values
# import/PadV2
# import/pool1
# import/fire2/squeeze1x1_weight
# import/fire2/squeeze1x1_weight/read
# import/convolution_1
# import/fire2/squeeze1x1_bias
# import/fire2/squeeze1x1_bias/read
# import/add_1
# import/fire2/relu_squeeze1x1
# import/fire2/expand1x1_weight
# import/fire2/expand1x1_weight/read
# import/convolution_2
# import/fire2/expand1x1_bias
# import/fire2/expand1x1_bias/read
# import/add_2
# import/Pad_1/paddings
# import/Pad_1
# import/fire2/expand3x3_weight
# import/fire2/expand3x3_weight/read
# import/convolution_3
# import/fire2/expand3x3_bias
# import/fire2/expand3x3_bias/read
# import/add_3
# import/fire2/relu_expand1x1
# import/fire2/relu_expand3x3
# import/fire2/concat/axis
# import/fire2/concat
# import/fire3/squeeze1x1_weight
# import/fire3/squeeze1x1_weight/read
# import/convolution_4
# import/fire3/squeeze1x1_bias
# import/fire3/squeeze1x1_bias/read
# import/add_4
# import/fire3/relu_squeeze1x1
# import/Pad_2/paddings
# import/Pad_2
# import/fire3/expand3x3_weight
# import/fire3/expand3x3_weight/read
# import/convolution_5
# import/fire3/expand3x3_bias
# import/fire3/expand3x3_bias/read
# import/add_5
# import/fire3/expand1x1_weight
# import/fire3/expand1x1_weight/read
# import/convolution_6
# import/fire3/expand1x1_bias
# import/fire3/expand1x1_bias/read
# import/add_6
# import/fire3/relu_expand3x3
# import/fire3/relu_expand1x1
# import/fire3/concat/axis
# import/fire3/concat
# import/fire4/squeeze1x1_weight
# import/fire4/squeeze1x1_weight/read
# import/convolution_7
# import/fire4/squeeze1x1_bias
# import/fire4/squeeze1x1_bias/read
# import/add_7
# import/fire4/relu_squeeze1x1
# import/fire4/expand1x1_weight
# import/fire4/expand1x1_weight/read
# import/convolution_8
# import/fire4/expand1x1_bias
# import/fire4/expand1x1_bias/read
# import/add_8
# import/Pad_3/paddings
# import/Pad_3
# import/fire4/expand3x3_weight
# import/fire4/expand3x3_weight/read
# import/convolution_9
# import/fire4/expand3x3_bias
# import/fire4/expand3x3_bias/read
# import/add_9
# import/fire4/relu_expand1x1
# import/fire4/relu_expand3x3
# import/fire4/concat/axis
# import/fire4/concat
# import/PadV2_1/paddings
# import/PadV2_1/constant_values
# import/PadV2_1
# import/pool4
# import/fire5/squeeze1x1_weight
# import/fire5/squeeze1x1_weight/read
# import/convolution_10
# import/fire5/squeeze1x1_bias
# import/fire5/squeeze1x1_bias/read
# import/add_10
# import/fire5/relu_squeeze1x1
# import/Pad_4/paddings
# import/Pad_4
# import/fire5/expand3x3_weight
# import/fire5/expand3x3_weight/read
# import/convolution_11
# import/fire5/expand3x3_bias
# import/fire5/expand3x3_bias/read
# import/add_11
# import/fire5/expand1x1_weight
# import/fire5/expand1x1_weight/read
# import/convolution_12
# import/fire5/expand1x1_bias
# import/fire5/expand1x1_bias/read
# import/add_12
# import/fire5/relu_expand3x3
# import/fire5/relu_expand1x1
# import/fire5/concat/axis
# import/fire5/concat
# import/fire6/squeeze1x1_weight
# import/fire6/squeeze1x1_weight/read
# import/convolution_13
# import/fire6/squeeze1x1_bias
# import/fire6/squeeze1x1_bias/read
# import/add_13
# import/fire6/relu_squeeze1x1
# import/fire6/expand1x1_weight
# import/fire6/expand1x1_weight/read
# import/convolution_14
# import/fire6/expand1x1_bias
# import/fire6/expand1x1_bias/read
# import/add_14
# import/Pad_5/paddings
# import/Pad_5
# import/fire6/expand3x3_weight
# import/fire6/expand3x3_weight/read
# import/convolution_15
# import/fire6/expand3x3_bias
# import/fire6/expand3x3_bias/read
# import/add_15
# import/fire6/relu_expand1x1
# import/fire6/relu_expand3x3
# import/fire6/concat/axis
# import/fire6/concat
# import/fire7/squeeze1x1_weight
# import/fire7/squeeze1x1_weight/read
# import/convolution_16
# import/fire7/squeeze1x1_bias
# import/fire7/squeeze1x1_bias/read
# import/add_16
# import/fire7/relu_squeeze1x1
# import/fire7/expand1x1_weight
# import/fire7/expand1x1_weight/read
# import/convolution_17
# import/fire7/expand1x1_bias
# import/fire7/expand1x1_bias/read
# import/add_17
# import/Pad_6/paddings
# import/Pad_6
# import/fire7/expand3x3_weight
# import/fire7/expand3x3_weight/read
# import/convolution_18
# import/fire7/expand3x3_bias
# import/fire7/expand3x3_bias/read
# import/add_18
# import/fire7/relu_expand1x1
# import/fire7/relu_expand3x3
# import/fire7/concat/axis
# import/fire7/concat
# import/fire8/squeeze1x1_weight
# import/fire8/squeeze1x1_weight/read
# import/convolution_19
# import/fire8/squeeze1x1_bias
# import/fire8/squeeze1x1_bias/read
# import/add_19
# import/fire8/relu_squeeze1x1
# import/fire8/expand1x1_weight
# import/fire8/expand1x1_weight/read
# import/convolution_20
# import/fire8/expand1x1_bias
# import/fire8/expand1x1_bias/read
# import/add_20
# import/Pad_7/paddings
# import/Pad_7
# import/fire8/expand3x3_weight
# import/fire8/expand3x3_weight/read
# import/convolution_21
# import/fire8/expand3x3_bias
# import/fire8/expand3x3_bias/read
# import/add_21
# import/fire8/relu_expand1x1
# import/fire8/relu_expand3x3
# import/fire8/concat/axis
# import/fire8/concat
# import/PadV2_2/paddings
# import/PadV2_2/constant_values
# import/PadV2_2
# import/pool8
# import/fire9/squeeze1x1_weight
# import/fire9/squeeze1x1_weight/read
# import/convolution_22
# import/fire9/squeeze1x1_bias
# import/fire9/squeeze1x1_bias/read
# import/add_22
# import/fire9/relu_squeeze1x1
# import/fire9/expand1x1_weight
# import/fire9/expand1x1_weight/read
# import/convolution_23
# import/fire9/expand1x1_bias
# import/fire9/expand1x1_bias/read
# import/add_23
# import/Pad_8/paddings
# import/Pad_8
# import/fire9/expand3x3_weight
# import/fire9/expand3x3_weight/read
# import/convolution_24
# import/fire9/expand3x3_bias
# import/fire9/expand3x3_bias/read
# import/add_24
# import/fire9/relu_expand1x1
# import/fire9/relu_expand3x3
# import/fire9/concat/axis
# import/fire9/concat
# import/Pad_9/paddings
# import/Pad_9
# import/conv10_weight
# import/conv10_weight/read
# import/convolution_25
# import/conv10_bias
# import/conv10_bias/read
# import/add_25
# import/relu_conv10
# import/pool10
# import/Shape
# import/Rank
# import/Shape_1
# import/Sub/y
# import/Sub
# import/Slice/begin
# import/Slice/size
# import/Slice
# import/concat/values_0
# import/concat/axis
# import/concat
# import/Reshape
# import/Softmax
# import/prob
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
layers = [op.name for op in graph.get_operations() if op.type=='Conv2D' and 'import/' in op.name]
feature_nums = [int(graph.get_tensor_by_name(name+':0').get_shape()[-1]) for name in layers]

print('Number of layers', len(layers))
print('Total number of feature channels:', sum(feature_nums))


# Helper functions for TF Graph visualization

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = tf.compat.as_bytes("<stripped %d bytes>"%size)
    return strip_def
  
def rename_nodes(graph_def, rename_func):
    res_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = res_def.node.add() 
        n.MergeFrom(n0)
        n.name = rename_func(n.name)
        for i, s in enumerate(n.input):
            n.input[i] = rename_func(s) if s[0]!='^' else '^'+rename_func(s[1:])
    return res_def
  
def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))
  
    iframe = """
        <iframe seamless style="width:800px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# Visualizing the network graph. Be sure expand the "mixed" nodes to see their 
# internal structure. We are going to visualize "Conv2D" nodes.
tmp_def = rename_nodes(graph_def, lambda s:"/".join(s.split('_',1)))
show_graph(tmp_def)
# Out:
# Number of layers 26
# Total number of feature channels: 3976
#         <iframe seamless style="width:800px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.495104245218&quot;).pbtxt = 'node {\n  name: &quot;data&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 227\n        }\n        dim {\n          size: 227\n        }\n        dim {\n          size: 3\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Pad/paddings&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\001\\000\\000\\000\\000\\000\\000\\000\\001\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Pad&quot;\n  op: &quot;Pad&quot;\n  input: &quot;data&quot;\n  input: &quot;Pad/paddings&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;Tpaddings&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weight&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 7\n          }\n          dim {\n            size: 7\n          }\n          dim {\n            size: 3\n          }\n          dim {\n            size: 96\n          }\n        }\n        tensor_content: &quot;<stripped 56448 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weight/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;conv1/weight&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1_weight&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;convolution&quot;\n  op: &quot;Conv2D&quot;\n  input: &quot;Pad&quot;\n  input: &quot;conv1/weight/read&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n  attr {\n    key: &quot;padding&quot;\n    value {\n      s: &quot;VALID&quot;\n    }\n  }\n  attr {\n    key: &quot;strides&quot;\n    value {\n      list {\n        i: 1\n        i: 2\n        i: 2\n        i: 1\n      }\n    }\n  }\n  attr {\n    key: &quot;use_cudnn_on_gpu&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;conv1/bias&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 96\n          }\n        }\n        tensor_content: &quot;<stripped 384 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/bias/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;conv1/bias&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1_bias&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;add&quot;\n  op: &quot;Add&quot;\n  input: &quot;convolution&quot;\n  input: &quot;conv1/bias/read&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;relu/conv1&quot;\n  op: &quot;Relu&quot;\n  input: &quot;add&quot;\n  attr {\n    key: &quot;T&quot;\n    value ...
