# %%
from __future__ import print_function
import os
from io import BytesIO
import numpy as np
from functools import partial
import PIL.Image
from IPython.display import clear_output, Image, display, HTML

import tensorflow as tf

# %%
model_fn = '/Users/chengli/frozen_model.pb'

# %%
# creating TensorFlow session and loading the model
graph = tf.Graph()
sess = tf.InteractiveSession(graph=graph)
with tf.gfile.FastGFile(model_fn, 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
t_input = tf.placeholder(np.float32, name='input') # define the input tensor
imagenet_mean = 117.0
t_preprocessed = tf.expand_dims(t_input-imagenet_mean, 0)
tf.import_graph_def(graph_def)
[print(n.name) for n in tf.get_default_graph().as_graph_def().node]
# Out:
# input
# sub/y
# sub
# ExpandDims/dim
# ExpandDims
# import/data
# import/Pad/paddings
# import/Pad
# import/conv1_weight
# import/conv1_weight/read
# import/convolution
# import/conv1_bias
# import/conv1_bias/read
# import/add
# import/relu1
# import/norm1
# import/PadV2/paddings
# import/PadV2/constant_values
# import/PadV2
# import/pool1
# import/Pad_1/paddings
# import/Pad_1
# import/conv2_weight
# import/conv2_weight/read
# import/split/split_dim
# import/split
# import/split_1/split_dim
# import/split_1
# import/convolution_1
# import/convolution_2
# import/concat/axis
# import/concat
# import/conv2_bias
# import/conv2_bias/read
# import/add_1
# import/relu2
# import/norm2
# import/PadV2_1/paddings
# import/PadV2_1/constant_values
# import/PadV2_1
# import/pool2
# import/Pad_2/paddings
# import/Pad_2
# import/conv3_weight
# import/conv3_weight/read
# import/convolution_3
# import/conv3_bias
# import/conv3_bias/read
# import/add_2
# import/relu3
# import/Pad_3/paddings
# import/Pad_3
# import/conv4_weight
# import/conv4_weight/read
# import/split_2/split_dim
# import/split_2
# import/split_3/split_dim
# import/split_3
# import/convolution_4
# import/convolution_5
# import/concat_1/axis
# import/concat_1
# import/conv4_bias
# import/conv4_bias/read
# import/add_3
# import/relu4
# import/Pad_4/paddings
# import/Pad_4
# import/conv5_weight
# import/conv5_weight/read
# import/split_4/split_dim
# import/split_4
# import/split_5/split_dim
# import/split_5
# import/convolution_6
# import/convolution_7
# import/concat_2/axis
# import/concat_2
# import/conv5_bias
# import/conv5_bias/read
# import/add_4
# import/relu5
# import/PadV2_2/paddings
# import/PadV2_2/constant_values
# import/PadV2_2
# import/pool5
# import/Flatten/flatten/Shape
# import/Flatten/flatten/strided_slice/stack
# import/Flatten/flatten/strided_slice/stack_1
# import/Flatten/flatten/strided_slice/stack_2
# import/Flatten/flatten/strided_slice
# import/Flatten/flatten/Reshape/shape/1
# import/Flatten/flatten/Reshape/shape
# import/Flatten/flatten/Reshape
# import/dense/kernel
# import/dense/kernel/read
# import/dense/bias
# import/dense/bias/read
# import/dense/MatMul
# import/dense/BiasAdd
# import/relu6
# import/Flatten_1/flatten/Shape
# import/Flatten_1/flatten/strided_slice/stack
# import/Flatten_1/flatten/strided_slice/stack_1
# import/Flatten_1/flatten/strided_slice/stack_2
# import/Flatten_1/flatten/strided_slice
# import/Flatten_1/flatten/Reshape/shape/1
# import/Flatten_1/flatten/Reshape/shape
# import/Flatten_1/flatten/Reshape
# import/dense_1/kernel
# import/dense_1/kernel/read
# import/dense_1/bias
# import/dense_1/bias/read
# import/dense_2/MatMul
# import/dense_2/BiasAdd
# import/relu7
# import/Flatten_2/flatten/Shape
# import/Flatten_2/flatten/strided_slice/stack
# import/Flatten_2/flatten/strided_slice/stack_1
# import/Flatten_2/flatten/strided_slice/stack_2
# import/Flatten_2/flatten/strided_slice
# import/Flatten_2/flatten/Reshape/shape/1
# import/Flatten_2/flatten/Reshape/shape
# import/Flatten_2/flatten/Reshape
# import/dense_2/kernel
# import/dense_2/kernel/read
# import/dense_2/bias
# import/dense_2/bias/read
# import/dense_3/MatMul
# import/dense_3/BiasAdd
# import/prob
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
layers = [op.name for op in graph.get_operations() if op.type=='Conv2D' and 'import/' in op.name]
feature_nums = [int(graph.get_tensor_by_name(name+':0').get_shape()[-1]) for name in layers]

print('Number of layers', len(layers))
print('Total number of feature channels:', sum(feature_nums))


# Helper functions for TF Graph visualization

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = tf.compat.as_bytes("<stripped %d bytes>"%size)
    return strip_def
  
def rename_nodes(graph_def, rename_func):
    res_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = res_def.node.add() 
        n.MergeFrom(n0)
        n.name = rename_func(n.name)
        for i, s in enumerate(n.input):
            n.input[i] = rename_func(s) if s[0]!='^' else '^'+rename_func(s[1:])
    return res_def
  
def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))
  
    iframe = """
        <iframe seamless style="width:800px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# Visualizing the network graph. Be sure expand the "mixed" nodes to see their 
# internal structure. We are going to visualize "Conv2D" nodes.
tmp_def = rename_nodes(graph_def, lambda s:"/".join(s.split('_',1)))
show_graph(tmp_def)
# Out:
# Number of layers 8
# Total number of feature channels: 1376
#         <iframe seamless style="width:800px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.507511254368&quot;).pbtxt = 'node {\n  name: &quot;data&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 227\n        }\n        dim {\n          size: 227\n        }\n        dim {\n          size: 3\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Pad/paddings&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\001\\000\\000\\000\\000\\000\\000\\000\\001\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Pad&quot;\n  op: &quot;Pad&quot;\n  input: &quot;data&quot;\n  input: &quot;Pad/paddings&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;Tpaddings&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weight&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 11\n          }\n          dim {\n            size: 11\n          }\n          dim {\n            size: 3\n          }\n          dim {\n            size: 96\n          }\n        }\n        tensor_content: &quot;<stripped 139392 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weight/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;conv1/weight&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1_weight&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;convolution&quot;\n  op: &quot;Conv2D&quot;\n  input: &quot;Pad&quot;\n  input: &quot;conv1/weight/read&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n  attr {\n    key: &quot;padding&quot;\n    value {\n      s: &quot;VALID&quot;\n    }\n  }\n  attr {\n    key: &quot;strides&quot;\n    value {\n      list {\n        i: 1\n        i: 4\n        i: 4\n        i: 1\n      }\n    }\n  }\n  attr {\n    key: &quot;use_cudnn_on_gpu&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;conv1/bias&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 96\n          }\n        }\n        tensor_content: &quot;<stripped 384 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/bias/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;conv1/bias&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1_bias&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;add&quot;\n  op: &quot;Add&quot;\n  input: &quot;convolution&quot;\n  input: &quot;conv1/bias/read&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;relu1&quot;\n  op: &quot;Relu&quot;\n  input: &quot;add&quot;\n  attr {\n    key: &quot;T&quot;\n    value { ...
